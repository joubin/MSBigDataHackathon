# %%
# %matplotlib inline
from pylab import *
import pandas as pd

# %%
crime = pd.read_csv('data/Crime_Map.csv')
crime.head()
# Out:
#    ﻿RMS CDW ID  General Offense Number  Offense Code  Offense Code Extension  \
# 0       464632              2015177936          2202                       0
# 1       464545              2015177683          2202                       0
# 2       464630              2015177690          2202                       0
# 3       464640              2015177735          2202                       0
# 4       464597              2015177663          2202                       0
#
#          Offense Type  Summary Offense Code Summarized Offense Description  \
# 0  BURGLARY-FORCE-RES                  2200                       BURGLARY
# 1  BURGLARY-FORCE-RES                  2200                       BURGLARY
# 2  BURGLARY-FORCE-RES                  2200                       BURGLARY
# 3  BURGLARY-FORCE-RES                  2200                       BURGLARY
# 4  BURGLARY-FORCE-RES                  2200                       BURGLARY
#
# ...

# %%
def gps_grid_magic(df, column = 'Offense Type', grid_size = 100, grid = ["Latitude", "Longitude"]):
    df = df.copy()
    for gi in grid:
        df[gi] =(df[gi]*grid_size).astype('int')

    return df.groupby(grid)[column].value_counts().unstack().fillna(0).reset_index()

gps_grid_magic(crime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-110304025177> in <module>()
#       6     return df.groupby(grid)[column].value_counts().unstack().fillna(0).reset_index()
#       7
# ----> 8 gps_grid_magic(crime)
#
# NameError: name 'crime' is not defined
